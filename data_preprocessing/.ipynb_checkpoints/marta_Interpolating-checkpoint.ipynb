# %%
import pandas as pd
import psycopg2
con = psycopg2.connect(host="istanbul.mathcs.emory.edu",database='adherencedb',user='dgarci8',password='8uSPred')
from sqlalchemy import create_engine
engine = create_engine('postgresql://dgarci8:8uSPred@istanbul.mathcs.emory.edu:5432/adherencedb')

# %%
dates = pd.read_sql("select distinct msgdate from gps_june_aug_updated_distinct",con)
print(dates.head())
print(len(unique(dates['msgdate'])))
# Out:
#       msgdate
# 0  2014-07-04
# 1  2014-07-27
# 2  2014-07-11
# 3  2014-08-01
# 4  2014-07-26
# 36

# %%
from scipy import interpolate
#fig, axs = plt.subplots(1,2,figsize=(15, 5))

for day in dates['msgdate']:
    print(day)
    data = pd.read_sql("select trip_id,stopseq,adherence from gps_june_aug_updated_distinct where msgdate = \'" + str(day) + "\'",con)
    data.sort(['trip_id','stopseq'],inplace=True)
    #print(data.head())
    data_ind = data.set_index('trip_id')
    #print(data_ind.head())
    complete_data = pd.DataFrame(columns=['msgdate','trip_id','stopseq','adherence'])
    trips = unique(data['trip_id'])
    #print trips
    for trip in trips:
        #print trip
        sequence = data_ind.ix[trip]
        #print sequence
        #ax1 = sequence.plot('stopseq','adherence',kind='scatter')
        #print(type(sequence))
        if(type(sequence) is pd.DataFrame):
            fi = interpolate.interp1d(sequence['stopseq'],sequence['adherence'])
            complete_seq = list(arange(min(sequence['stopseq']),max(sequence['stopseq'])+1,1))
            complete_ad = [0] * len(complete_seq)
            for i in arange(len(complete_seq)):
                complete_ad[i] = fi(complete_seq[i])
            complete_sequence = pd.DataFrame(columns=['msgdate','trip_id','stopseq','adherence'])  
            complete_sequence['msgdate'] = [day]*len(complete_seq)
            complete_sequence['trip_id'] = [trip]*len(complete_seq)
            complete_sequence['stopseq'] = complete_seq
            complete_sequence['adherence'] = complete_ad
            #print(complete_sequence)    
            #ax1.plot(complete_sequence['stopseq'],complete_sequence['adherence'])
            complete_data = pd.concat([complete_data,complete_sequence])
    complete_data.to_sql("gps_june_aug_interpolated",engine,index=False,if_exists='append')
# Out:
# 2014-07-04
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# <class 'pandas.core.frame.DataFrame'>
# working
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-d8873234f9aa> in <module>()
#      32             #print(complete_sequence)
#      33             #ax1.plot(complete_sequence['stopseq'],complete_sequence['adherence'])
# ---> 34             complete_data = pd.concat([complete_data,complete_sequence])
#      35     #complete_data.to_sql("gps_june_aug_interpolated",engine,index=False,if_exists='append')
#
# C:\Users\LAYLA\Anaconda\lib\site-packages\pandas\tools\merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity)
#     715                        ignore_index=ignore_index, join=join,
#     716                        keys=keys, levels=levels, names=names,
# --> 717                        verify_integrity=verify_integrity)
#     718     return op.get_result()
#     719
#
# C:\Users\LAYLA\Anaconda\lib\site-packages\pandas\tools\merge.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity)
#     786             # filter out the empties
#     787             # if we have not multi-index possibiltes
# --> 788             df = DataFrame([ obj.shape for obj in objs ]).sum(1)
#     789             non_empties = df[df!=0]
#     790             if len(non_empties) and (keys is None and names is None and levels is None and join_axes is None):
#
# C:\Users\LAYLA\Anaconda\lib\site-packages\pandas\core\frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     247                         index = _default_index(len(data))
#     248                     mgr = _arrays_to_mgr(arrays, columns, index, columns,
# --> 249                                          dtype=dtype)
#     250                 else:
#     251                     mgr = self._init_ndarray(data, index, columns, dtype=dtype,
#
# C:\Users\LAYLA\Anaconda\lib\site-packages\pandas\core\frame.pyc in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    4628     axes = [_ensure_index(columns), _ensure_index(index)]
#    4629
# -> 4630     return create_block_manager_from_arrays(arrays, arr_names, axes)
#    4631
#    4632
#
# C:\Users\LAYLA\Anaconda\lib\site-packages\pandas\core\internals.pyc in create_block_manager_from_arrays(arrays, names, axes)
#    3233 def create_block_manager_from_arrays(arrays, names, axes):
#    3234     try:
# -> 3235         blocks = form_blocks(arrays, names, axes)
#    3236         mgr = BlockManager(blocks, axes)
#    3237         mgr._consolidate_inplace()
#
# C:\Users\LAYLA\Anaconda\lib\site-packages\pandas\core\internals.pyc in form_blocks(arrays, names, axes)
#    3254
#    3255     names_idx = Index(names)
# -> 3256     if names_idx.equals(axes[0]):
#    3257         names_indexer = np.arange(len(names_idx))
#    3258     else:
#
# C:\Users\LAYLA\Anaconda\lib\site-packages\pandas\core\index.pyc in equals(self, other)
#    1924
#    1925         try:
# -> 1926             return array_equivalent(self, other)
#    1927         except TypeError:
#    1928             # e.g. fails in numpy 1.6 with DatetimeIndex #1681
#
# C:\Users\LAYLA\Anaconda\lib\site-packages\pandas\core\common.pyc in array_equivalent(left, right)
#     329     if issubclass(left.dtype.type, (np.floating, np.complexfloating)):
#     330         return ((left == right) | (np.isnan(left) & np.isnan(right))).all()
# --> 331     return np.array_equal(left, right)
#     332
#     333 def _iterable_not_string(x):
#
# C:\Users\LAYLA\Anaconda\lib\site-packages\numpy\core\numeric.pyc in array_equal(a1, a2)
#    2259     if a1.shape != a2.shape:
#    2260         return False
# -> 2261     return bool(asarray(a1 == a2).all())
#    2262
#    2263 def array_equiv(a1, a2):
#
# C:\Users\LAYLA\Anaconda\lib\site-packages\numpy\core\_methods.pyc in _all(a, axis, dtype, out, keepdims)
#      35 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
#      36     return um.logical_and.reduce(a, axis=axis, dtype=dtype, out=out,
# ---> 37                                  keepdims=keepdims)
#      38
#      39 def _count_reduce_items(arr, axis):
#
# KeyboardInterrupt:
